# %%
import pandas as pd

# %%
df = pd.read_excel (r'S:\can\retail\retail sales intelligence\Wealth\Reports - Scheduled\2 - Monthly Reports\SMA\SMA Data Files\SMA Reports-Python\BMO Cash Flow.xlsx', sheet_name='Cash_Flow_Date_crosstab (9)')

# %%
df.head()
# Out:
#        Model / Manager Name                    Sponsor Name Curr  \
# 0  Manulife Canadian Equity  Manulife Asset Mgmt             CAD
# 1  Manulife Canadian Equity  Manulife Asset Mgmt             CAD
# 2  Manulife Canadian Equity  Manulife Asset Mgmt             CAD
# 3  Manulife Canadian Equity  Manulife Asset Mgmt             CAD
# 4  Manulife Canadian Equity  Manulife Asset Mgmt             CAD
#
#   Account System ID Cash Flow Date  Cash Flow Amount  Holding Flow Amount
# 0         U00000624     12/10/2021             -6.98                  0.0
# 1         U00000624     12/16/2021             -7.13                  0.0
# 2         U00000624     12/17/2021             -5.06                  0.0
# 3         U00000624      12/2/2021            -39.25                  0.0
# 4         U00000624     12/24/2021             -3.06                  0.0

# %%
dff.insert(loc=0, column='Platform', value='BMO Architect', allow_duplicates=True)

# %%
df.drop_duplicates(subset='Platform')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13704/4008227253.py in <module>
# ----> 1 df2.drop_duplicates(subset='Platform')
#
# NameError: name 'df2' is not defined

# %%
dff.head(5)
# Out:
#                      Sponsor Name       Platform       Platform  \
# 0  Manulife Asset Mgmt             BMO Architect  BMO Architect
# 1  Manulife Asset Mgmt             BMO Architect  BMO Architect
# 2  Manulife Asset Mgmt             BMO Architect  BMO Architect
# 3  Manulife Asset Mgmt             BMO Architect  BMO Architect
# 4  Manulife Asset Mgmt             BMO Architect  BMO Architect
#
#         Platform       Platform       Platform Platform  \
# 0  BMO Architect  BMO Architect  BMO Architect      BMO
# 1  BMO Architect  BMO Architect  BMO Architect      BMO
# 2  BMO Architect  BMO Architect  BMO Architect      BMO
# 3  BMO Architect  BMO Architect  BMO Architect      BMO
# 4  BMO Architect  BMO Architect  BMO Architect      BMO
#
#        Model / Manager Name Curr Cash Flow Date  Cash Flow Amount
# 0  Manulife Canadian Equity  CAD     12/10/2021             -6.98
# 1  Manulife Canadian Equity  CAD     12/16/2021             -7.13
# ...

# %%
dff.drop_duplicates()
# Out:
#            Platform       Platform                    Sponsor Name  \
# 0     BMO Architect  BMO Architect  Manulife Asset Mgmt
# 1     BMO Architect  BMO Architect  Manulife Asset Mgmt
# 2     BMO Architect  BMO Architect  Manulife Asset Mgmt
# 3     BMO Architect  BMO Architect  Manulife Asset Mgmt
# 4     BMO Architect  BMO Architect  Manulife Asset Mgmt
# ...             ...            ...                             ...
# 1377  BMO Architect  BMO Architect  Manulife Asset Mgmt
# 1378  BMO Architect  BMO Architect  Manulife Asset Mgmt
# 1379  BMO Architect  BMO Architect  Manulife Asset Mgmt
# 1380  BMO Architect  BMO Architect  Manulife Asset Mgmt
# 1381  BMO Architect  BMO Architect  Manulife Asset Mgmt
#
#            Platform       Platform       Platform       Platform  \
# 0     BMO Architect  BMO Architect  BMO Architect  BMO Architect
# 1     BMO Architect  BMO Architect  BMO Architect  BMO Architect
# 2     BMO Architect  BMO Architect  BMO Architect  BMO Architect
# ...

# %%
df1 = pd.DataFrame(df, columns= ['Platform','Sponsor Name','Model / Manager Name','Curr','Cash Flow Date','Cash Flow Amount'])

# %%
df1.head()
# Out:
#    Platform                    Sponsor Name      Model / Manager Name Curr  \
# 0       NaN  Manulife Asset Mgmt             Manulife Canadian Equity  CAD
# 1       NaN  Manulife Asset Mgmt             Manulife Canadian Equity  CAD
# 2       NaN  Manulife Asset Mgmt             Manulife Canadian Equity  CAD
# 3       NaN  Manulife Asset Mgmt             Manulife Canadian Equity  CAD
# 4       NaN  Manulife Asset Mgmt             Manulife Canadian Equity  CAD
#
#   Cash Flow Date  Cash Flow Amount
# 0     12/10/2021             -6.98
# 1     12/16/2021             -7.13
# 2     12/17/2021             -5.06
# 3      12/2/2021            -39.25
# 4     12/24/2021             -3.06

# %%
dff.insert(loc=1, column='Platform', value='BMO Architect', allow_duplicates=True)

# %%
dff.head()
# Out:
#                      Sponsor Name       Platform Platform  \
# 0  Manulife Asset Mgmt             BMO Architect      BMO
# 1  Manulife Asset Mgmt             BMO Architect      BMO
# 2  Manulife Asset Mgmt             BMO Architect      BMO
# 3  Manulife Asset Mgmt             BMO Architect      BMO
# 4  Manulife Asset Mgmt             BMO Architect      BMO
#
#        Model / Manager Name Curr Cash Flow Date  Cash Flow Amount
# 0  Manulife Canadian Equity  CAD     12/10/2021             -6.98
# 1  Manulife Canadian Equity  CAD     12/16/2021             -7.13
# 2  Manulife Canadian Equity  CAD     12/17/2021             -5.06
# 3  Manulife Canadian Equity  CAD      12/2/2021            -39.25
# 4  Manulife Canadian Equity  CAD     12/24/2021             -3.06

# %%
groupby_df= dff.groupby(['Model / Manager Name'])

# %%
groupby_df.head()
# Out:
#                         Sponsor Name           Model / Manager Name Curr  \
# 0     Manulife Asset Mgmt                  Manulife Canadian Equity  CAD
# 1     Manulife Asset Mgmt                  Manulife Canadian Equity  CAD
# 2     Manulife Asset Mgmt                  Manulife Canadian Equity  CAD
# 3     Manulife Asset Mgmt                  Manulife Canadian Equity  CAD
# 4     Manulife Asset Mgmt                  Manulife Canadian Equity  CAD
# ...                              ...                            ...  ...
# 1377  Manulife Asset Mgmt             Manulife U.S. Dividend Equity  USD
# 1378  Manulife Asset Mgmt             Manulife U.S. Dividend Equity  USD
# 1379  Manulife Asset Mgmt             Manulife U.S. Dividend Equity  USD
# 1380  Manulife Asset Mgmt             Manulife U.S. Dividend Equity  USD
# 1381  Manulife Asset Mgmt             Manulife U.S. Dividend Equity  USD
#
#      Cash Flow Date  Cash Flow Amount
# 0        12/10/2021             -6.98
# ...

# %%
df1 = pd.read_excel (r'S:\can\retail\retail sales intelligence\Wealth\Reports - Scheduled\2 - Monthly Reports\SMA\SMA Data Files\2021\2021-12\BMO\Monthly_AUM_by_Client_Report__crosstab (December 2021)Manulife.xlsx', sheet_name='BMO AUM Dec21')

# %%
df.head()
# Out:
#        Model / Manager Name                    Sponsor Name Curr  \
# 0  Manulife Canadian Equity  Manulife Asset Mgmt             CAD
# 1  Manulife Canadian Equity  Manulife Asset Mgmt             CAD
# 2  Manulife Canadian Equity  Manulife Asset Mgmt             CAD
# 3  Manulife Canadian Equity  Manulife Asset Mgmt             CAD
# 4  Manulife Canadian Equity  Manulife Asset Mgmt             CAD
#
#   Account System ID Cash Flow Date  Cash Flow Amount  Holding Flow Amount  \
# 0         U00000672      12/2/2021           1134.83                  0.0
# 1         U00006581     12/23/2021              6.33                  0.0
# 2         U00007170     12/29/2021          71460.77                  0.0
# 3         U00007561      12/3/2021           4808.59                  0.0
# 4         U00015305     12/17/2021              0.00            -170537.0
#
#   Reporting Date    Type
# 0     2021-12-31  Inflow
# 1     2021-12-31  Inflow
# 2     2021-12-31  Inflow
# ...
