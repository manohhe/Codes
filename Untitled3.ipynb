# %%
import pandas as pd
import datetime as dt
import numpy as np
import sqlite3
import openpyxl as xl

# %%
df = pd.read_csv (r'C:\Users\manohhe\OneDrive - Manulife\WAM Intelligence\Projects\MRAIF\Pending Trades Report\2022-05\20220530-MMFMRAIFPENDTRD30050630.txt', sep="|")
df
# Out:
#      Account Number Alt Account Number Subscription Status AcctCategory  \
# 0          18839977           03V6676S          SA on File       GARSDA
# 1          20501995           03V6843S          SA on File       GARSDA
# 2          20970612           NFH4786S          SA on File       GARSDA
# 3          21218896           NFS2852A          SA on File        GARS1
# 4          24051203           NFA6401R          SA on File       GARSDA
# ..              ...                ...                 ...          ...
# 848     18012827001           NFJ0879A          SA on File        GARS1
# 849     18012833001           NFJ0879R          SA on File        GARS1
# 850     18012850001         3769761416          SA on File       GARSDA
# 851     18012969001            11Y64EE          Missing SA          NaN
# 852     18013011001            1CUAMEE          Missing SA          NaN
#
#      Baycom  Process Date  Trade Date Transaction Type         Amount  \
# ...

# %%
df_1 = df.to_excel(r'C:\Users\manohhe\OneDrive - Manulife\WAM Intelligence\Member - Hemapriya\Ad Hoc\20220530-MMFMRAIFPENDTRD30050630output.xlsx', 'Sheet1', index=False)
df_1

# %%
df_2 = pd.read_csv (r'C:\Users\manohhe\OneDrive - Manulife\WAM Intelligence\Member - Hemapriya\Ad Hoc\20220831-MMFMRAIFPENDTRD31080630.txt', sep="|")
df_2
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 df_2 = pd.read_csv (r'C:\Users\manohhe\OneDrive - Manulife\WAM Intelligence\Member - Hemapriya\Ad Hoc\20220831-MMFMRAIFPENDTRD31080630.txt', sep="|")
#       2 df_2
#
# File ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
