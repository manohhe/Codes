# %%
import pandas as pd
import numpy as np
import openpyxl as xl

# %%
df = pd.read_csv (r'C:\Users\manohhe\OneDrive - Manulife\WAM Intelligence\Projects\MRAIF\Pending Trades Report\2022-05\20220530-MMFMRAIFPENDTRD30050630.txt', sep="|")
df
# Out:
#      Account Number Alt Account Number Subscription Status AcctCategory  \
# 0          18839977           03V6676S          SA on File       GARSDA
# 1          20501995           03V6843S          SA on File       GARSDA
# 2          20970612           NFH4786S          SA on File       GARSDA
# 3          21218896           NFS2852A          SA on File        GARS1
# 4          24051203           NFA6401R          SA on File       GARSDA
# ..              ...                ...                 ...          ...
# 848     18012827001           NFJ0879A          SA on File        GARS1
# 849     18012833001           NFJ0879R          SA on File        GARS1
# 850     18012850001         3769761416          SA on File       GARSDA
# 851     18012969001            11Y64EE          Missing SA          NaN
# 852     18013011001            1CUAMEE          Missing SA          NaN
#
#      Baycom  Process Date  Trade Date Transaction Type         Amount  \
# ...

# %%
df_1 = pd.read_csv (r'C:\Users\manohhe\OneDrive - Manulife\WAM Intelligence\Projects\MRAIF\Pending Trades Report\2022-08\20220831-MMFMRAIFPENDTRD31080630.txt', sep="|", encoding='latin-1')
df_1
# Out:
#      Account Number Alt Account Number Subscription Status AcctCategory  \
# 0       14263741001           NFS1959R          SA on File       GARSDA
# 1       14268815001           NFS0802R          SA on File       GARSDA
# 2       14268942001           NFS0803R          SA on File       GARSDA
# 3       14270756001           N259503R          SA on File       GARSDA
# 4       14273778001           NFS1445R          SA on File       GARSDA
# ..              ...                ...                 ...          ...
# 614     18066140001            6DG88KA          SA on File       GARSDA
# 615     18066141001            6DG7NNZ          SA on File       GARSDA
# 616     18066171001           1K9WVME0          SA on File       GARSDA
# 617     18066176001        800488306NM          Missing SA          NaN
# 618     16787239001           N388126R          SA on File        GARS1
#
#      Baycom  Process Date  Trade Date Transaction Type        Amount  \
# ...

# %%
df_2=pd.concat([df,df_1])

# %%
df_2
# Out:
#      Account Number Alt Account Number Subscription Status AcctCategory  \
# 0          18839977           03V6676S          SA on File       GARSDA
# 1          20501995           03V6843S          SA on File       GARSDA
# 2          20970612           NFH4786S          SA on File       GARSDA
# 3          21218896           NFS2852A          SA on File        GARS1
# 4          24051203           NFA6401R          SA on File       GARSDA
# ..              ...                ...                 ...          ...
# 614     18066140001            6DG88KA          SA on File       GARSDA
# 615     18066141001            6DG7NNZ          SA on File       GARSDA
# 616     18066171001           1K9WVME0          SA on File       GARSDA
# 617     18066176001        800488306NM          Missing SA          NaN
# 618     16787239001           N388126R          SA on File        GARS1
#
#      Baycom  Process Date  Trade Date Transaction Type        Amount  \
# ...

# %%
df_2.to_excel(r'C:\Users\manohhe\OneDrive - Manulife\WAM Intelligence\Projects\MRAIF\Pending Trades Report\Test_OutputFile.xlsx', 'Sheet1', index=False)
